# %%
import pandas as pd
from se_analysis import project
import nrgpy

# %%
file_path = project("Keene Branch FL", "MET1", "MDC_TCP_10_185_192_60_ALL 2026-08-21_08_54_39.txt")

# %%
df = pd.read_csv(file_path, delimiter="\t")
df.head()

# %%
for c in df.columns:
    print(c)
