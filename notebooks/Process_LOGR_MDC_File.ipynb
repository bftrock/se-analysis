# %% [markdown]
# This template is used to read Modbus Data Client (MDC) files collected by connecting directly to a LOGR Solar.

# %%
import pandas as pd
from se_analysis import project
import nrgpy

# %% [markdown]
# Set up data directory by using `project` to find your configured project directory. This is set in the `SE_PROJECTS_DIR` variable in the .env file.

# %%
file_path = project("SRM", "Keene-Branch_FL", "MET1", "MDC_TCP_10_185_192_60_ALL 2026-08-21_08_54_39.txt")

# %% [markdown]
# Read the file with pandas and specifying that it is tab-delimited.

# %%
df = pd.read_csv(file_path, delimiter="\t")
df
